# %%
import pandas as pd
from pathlib import Path
from collections import Counter

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Importing csv into a DataFrame

file_path = 'clean_covid_data.csv'
cleaned_df = pd.read_csv(file_path)
cleaned_df.head()
# Out:
#   Age_Group       Condition_Group                Condition  Deaths     Risk
# 0      0-24  Respiratory diseases  Influenza and pneumonia    1430     high
# 1     25-34  Respiratory diseases  Influenza and pneumonia    5647  highest
# 2     35-44  Respiratory diseases  Influenza and pneumonia   14738  highest
# 3     45-54  Respiratory diseases  Influenza and pneumonia   36674  highest
# 4     55-64  Respiratory diseases  Influenza and pneumonia   80438  highest

# %%
# Creating a sample dataframe for training

sample_df = cleaned_df.sample(frac=0.5, replace=True, random_state=1)

# %%
# Creating features
X = pd.get_dummies(sample_df, columns=['Age_Group', 'Condition_Group', 'Condition', 'Deaths']).drop('Risk', axis=1)

# Creating target
y = sample_df['Risk']
X.head()
# Out:
#         Age_Group_0-24  Age_Group_25-34  Age_Group_35-44  Age_Group_45-54  \
# 128037               0                0                0                0
# 229611               0                0                1                0
# 208780               0                1                0                0
# 5192                 0                0                0                0
# 229119               1                0                0                0
#
#         Age_Group_55-64  Age_Group_65-74  Age_Group_75-84  Age_Group_85+  \
# 128037                1                0                0              0
# 229611                0                0                0              0
# 208780                0                0                0              0
# 5192                  0                0                1              0
# 229119                0                0                0              0
#
#         Condition_Group_All other conditions and causes (residual)  \
# 128037                                                  0
# 229611                                                  0
# 208780                                                  0
# 5192                                                    0
# 229119                                                  0
#
#         Condition_Group_Alzheimer disease  ...  Deaths_68876  Deaths_79412  \
# 128037                                  0  ...             0             0
# 229611                                  0  ...             0             0
# 208780                                  0  ...             0             0
# 5192                                    0  ...             0             0
# 229119                                  0  ...             0             0
#
#         Deaths_95253  Deaths_106897  Deaths_110753  Deaths_110981  \
# 128037             0              0              0              0
# 229611             0              0              0              0
# 208780             0              0              0              0
# 5192               0              0              0              0
# 229119             0              0              0              0
#
#         Deaths_122785  Deaths_123714  Deaths_152680  Deaths_240927
# 128037              0              0              0              0
# 229611              0              0              0              0
# 208780              0              0              0              0
# 5192                0              0              0              0
# 229119              0              0              0              0
#
# [5 rows x 2062 columns]

# %%
X.describe()
# Out:
#        Age_Group_0-24  Age_Group_25-34  Age_Group_35-44  Age_Group_45-54  \
# count   125772.000000    125772.000000    125772.000000    125772.000000
# mean         0.156927         0.140635         0.125831         0.115646
# std          0.363733         0.347646         0.331660         0.319801
# min          0.000000         0.000000         0.000000         0.000000
# 25%          0.000000         0.000000         0.000000         0.000000
# 50%          0.000000         0.000000         0.000000         0.000000
# 75%          0.000000         0.000000         0.000000         0.000000
# max          1.000000         1.000000         1.000000         1.000000
#
#        Age_Group_55-64  Age_Group_65-74  Age_Group_75-84  Age_Group_85+  \
# count    125772.000000    125772.000000    125772.000000  125772.000000
# mean          0.111758         0.115582         0.117125       0.116497
# std           0.315069         0.319724         0.321570       0.320821
# min           0.000000         0.000000         0.000000       0.000000
# 25%           0.000000         0.000000         0.000000       0.000000
# 50%           0.000000         0.000000         0.000000       0.000000
# 75%           0.000000         0.000000         0.000000       0.000000
# max           1.000000         1.000000         1.000000       1.000000
#
#        Condition_Group_All other conditions and causes (residual)  \
# count                                      125772.000000
# mean                                            0.043213
# std                                             0.203337
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Condition_Group_Alzheimer disease  ...   Deaths_68876   Deaths_79412  \
# count                      125772.000000  ...  125772.000000  125772.000000
# mean                            0.052134  ...       0.000008       0.000008
# std                             0.222298  ...       0.002820       0.002820
# min                             0.000000  ...       0.000000       0.000000
# 25%                             0.000000  ...       0.000000       0.000000
# 50%                             0.000000  ...       0.000000       0.000000
# 75%                             0.000000  ...       0.000000       0.000000
# max                             1.000000  ...       1.000000       1.000000
#
#         Deaths_95253  Deaths_106897  Deaths_110753  Deaths_110981  \
# count  125772.000000  125772.000000  125772.000000  125772.000000
# mean        0.000008       0.000008       0.000008       0.000008
# std         0.002820       0.002820       0.002820       0.002820
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        Deaths_122785  Deaths_123714  Deaths_152680  Deaths_240927
# count  125772.000000  125772.000000  125772.000000  125772.000000
# mean        0.000008       0.000016       0.000008       0.000008
# std         0.002820       0.003988       0.002820       0.002820
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 2062 columns]

# %%
y.value_counts()
# Out:
# no risk    78804
# low        35590
# medium      8221
# high        2083
# highest     1074
# Name: Risk, dtype: int64

# %%
# Splitting dataset into training data and testing data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.shape
# Out:
# (94329, 2062)

# %%
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({'no risk': 59166, 'low': 26655, 'medium': 6121, 'high': 1555, 'highest': 832})
# Counter({'no risk': 19638, 'low': 8935, 'medium': 2100, 'high': 528, 'highest': 242})

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
# Instantiate
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)

# %%
# Fit
brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7378198423306019

# %%
# Display the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[  312,   148,    10,    58,     0],
#        [   57,   164,     4,    17,     0],
#        [  424,   694,  7595,   206,    16],
#        [  387,   468,    47,  1198,     0],
#        [    0,     0,     0,     0, 19638]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#        high       0.26      0.59      0.97      0.37      0.76      0.55       528
#     highest       0.11      0.68      0.96      0.19      0.81      0.63       242
#         low       0.99      0.85      1.00      0.92      0.92      0.84      8935
#      medium       0.81      0.57      0.99      0.67      0.75      0.54      2100
#     no risk       1.00      1.00      1.00      1.00      1.00      1.00     19638
#
# avg / total       0.97      0.92      1.00      0.94      0.95      0.91     31443
