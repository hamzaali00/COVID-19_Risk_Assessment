# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import os

# %%
file_path = "Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2022.csv"

covid_data_df = pd.read_csv(file_path, index_col=False)
covid_data_df.head()
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  10/16/2022  01/01/2020  10/15/2022  By Total   NaN    NaN  United States
# 1  10/16/2022  01/01/2020  10/15/2022  By Total   NaN    NaN  United States
# 2  10/16/2022  01/01/2020  10/15/2022  By Total   NaN    NaN  United States
# 3  10/16/2022  01/01/2020  10/15/2022  By Total   NaN    NaN  United States
# 4  10/16/2022  01/01/2020  10/15/2022  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0           1430.0              1495.0  NaN
# 1           5647.0              5860.0  NaN
# 2          14738.0             15345.0  NaN
# 3          36674.0             38105.0  NaN
# 4          80438.0             83347.0  NaN

# %%
covid_data_df = covid_data_df.drop(columns=['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month', 'State', 'ICD10_codes', 'Number of Mentions', 'Flag'])

# %%
covid_data_df = covid_data_df.dropna()

# %%
covid_data_df = covid_data_df[covid_data_df['Age Group'] != 'All Ages']
covid_data_df
# Out:
#              Condition Group                Condition   Age Group  \
# 0       Respiratory diseases  Influenza and pneumonia        0-24
# 1       Respiratory diseases  Influenza and pneumonia       25-34
# 2       Respiratory diseases  Influenza and pneumonia       35-44
# 3       Respiratory diseases  Influenza and pneumonia       45-54
# 4       Respiratory diseases  Influenza and pneumonia       55-64
# ...                      ...                      ...         ...
# 471921              COVID-19                 COVID-19  Not stated
# 471922              COVID-19                 COVID-19  Not stated
# 471923              COVID-19                 COVID-19  Not stated
# 471924              COVID-19                 COVID-19  Not stated
# 471925              COVID-19                 COVID-19  Not stated
#
#         COVID-19 Deaths
# 0                1430.0
# 1                5647.0
# 2               14738.0
# 3               36674.0
# 4               80438.0
# ...                 ...
# 471921              0.0
# 471922              0.0
# 471923              0.0
# 471924              0.0
# 471925              0.0
#
# [298519 rows x 4 columns]

# %%
covid_data_df = covid_data_df[covid_data_df['Age Group'] != 'Not stated']
covid_data_df
# Out:
#              Condition Group                Condition Age Group  \
# 0       Respiratory diseases  Influenza and pneumonia      0-24
# 1       Respiratory diseases  Influenza and pneumonia     25-34
# 2       Respiratory diseases  Influenza and pneumonia     35-44
# 3       Respiratory diseases  Influenza and pneumonia     45-54
# 4       Respiratory diseases  Influenza and pneumonia     55-64
# ...                      ...                      ...       ...
# 471887              COVID-19                 COVID-19       85+
# 471888              COVID-19                 COVID-19       85+
# 471889              COVID-19                 COVID-19       85+
# 471890              COVID-19                 COVID-19       85+
# 471891              COVID-19                 COVID-19       85+
#
#         COVID-19 Deaths
# 0                1430.0
# 1                5647.0
# 2               14738.0
# 3               36674.0
# 4               80438.0
# ...                 ...
# 471887             95.0
# 471888             74.0
# 471889             90.0
# 471890             71.0
# 471891             14.0
#
# [251543 rows x 4 columns]

# %%
covid_data_df = covid_data_df.set_index('Age Group')
covid_data_df.head()
# Out:
#                 Condition Group                Condition  COVID-19 Deaths
# Age Group
# 0-24       Respiratory diseases  Influenza and pneumonia           1430.0
# 25-34      Respiratory diseases  Influenza and pneumonia           5647.0
# 35-44      Respiratory diseases  Influenza and pneumonia          14738.0
# 45-54      Respiratory diseases  Influenza and pneumonia          36674.0
# 55-64      Respiratory diseases  Influenza and pneumonia          80438.0

# %%
covid_data_df = covid_data_df.rename(columns={'Age Group': 'Age_Group', 'Condition Group': 'Condition_Group', 'COVID-19 Deaths': 'Deaths'})

# %%
covid_data_df.head()
# Out:
#                 Condition_Group                Condition   Deaths
# Age Group
# 0-24       Respiratory diseases  Influenza and pneumonia   1430.0
# 25-34      Respiratory diseases  Influenza and pneumonia   5647.0
# 35-44      Respiratory diseases  Influenza and pneumonia  14738.0
# 45-54      Respiratory diseases  Influenza and pneumonia  36674.0
# 55-64      Respiratory diseases  Influenza and pneumonia  80438.0

# %%
covid_data_df = covid_data_df.astype({'Deaths': 'int64'})
covid_data_df.head()
# Out:
#                 Condition_Group                Condition  Deaths
# Age Group
# 0-24       Respiratory diseases  Influenza and pneumonia    1430
# 25-34      Respiratory diseases  Influenza and pneumonia    5647
# 35-44      Respiratory diseases  Influenza and pneumonia   14738
# 45-54      Respiratory diseases  Influenza and pneumonia   36674
# 55-64      Respiratory diseases  Influenza and pneumonia   80438

# %%
bins = [-1, 0, 100, 500, 1500, 280000]
labels = ['no risk', 'low', 'medium', 'high', 'highest']
covid_data_df['Risk'] = pd.cut(covid_data_df['Deaths'], bins=bins, labels=labels)
covid_data_df.head()
# Out:
#                 Condition_Group                Condition  Deaths     Risk
# Age Group
# 0-24       Respiratory diseases  Influenza and pneumonia    1430     high
# 25-34      Respiratory diseases  Influenza and pneumonia    5647  highest
# 35-44      Respiratory diseases  Influenza and pneumonia   14738  highest
# 45-54      Respiratory diseases  Influenza and pneumonia   36674  highest
# 55-64      Respiratory diseases  Influenza and pneumonia   80438  highest

# %%
covid_data_df.to_csv('clean_covid_data.csv')
